# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Fiona Tirmizi**

# %% [markdown]
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because I would like to be able to manipulate, read, and tell stories from data driven insights. My organization and career will benefit from my skills in this area_

# %% [markdown]
# ### My code will answer whether a particular statement is true or false

# %%
if 5>6:
    print("True");
else:
    print("False")
# Out:
# False

# %% [markdown]
# |Name|Age|Company|Link|
# |----|---|-------|----|
# |Fiona|27|IBM|[IBM official site](https://www.ibm.com/uk-en?utm_content=SRCWW&p1=Search&p4=43700068848979164&p5=e&gclid=Cj0KCQjwguGYBhDRARIsAHgRm48LNqQNnRbDyEZ6Sa1_Oajby1ZYk-a7IvfI5tBajhw3YFua8xZTyFQaAo8zEALw_wcB&gclsrc=aw.ds)|
# |Julia|45|McDermott|[McDermott official site](https://www.mcdermott.com/)|
# |~Nikhita~|~33~|~Microsoft~|[Microsoft official site](https://www.microsoft.com/en-gulf/)|
